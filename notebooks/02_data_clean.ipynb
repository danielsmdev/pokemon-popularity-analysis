# %% [markdown]
# ### Añadimos SRC a la raíz del proyecto para poder importar el contenido

# %%
import sys
import os

# Obtener la ruta absoluta de la carpeta raíz (donde está src)
ROOT_DIR = os.path.abspath(os.path.join(os.getcwd(), ".."))  # Subir un nivel desde notebooks/

# Agregar la carpeta src al path
sys.path.append(os.path.join(ROOT_DIR, "src"))

# %% [markdown]
# ### Importamos los módulos necesarios

# %%
import pandas as pd
import time
from pokemon_api import get_pokemon_names, get_all_forms, get_pokemon_data, get_species_data, clean_pokemon_name
from data_processing import save_partial_data, filter_pokemon_variants
from config import PARTIAL_SAVE_PATH_DATA_COLLECTION, FINAL_SAVE_PATH_DATA_COLLECTION, FILTER_DATA_PATH, SORTED_FILTER_DATA_PATH, SORTED_FILTER_DATA_PATH_CLEANED, FINAL_DATASET_PATH

# %% [markdown]
# ### Cargamos el dataset recolectado en 01_data_collection.ipynb

# %%
# Cargar el dataset original
df_pokemon = pd.read_csv(FINAL_SAVE_PATH_DATA_COLLECTION)

# %%
df_pokemon.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1233 entries, 0 to 1232
# Data columns (total 16 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   index           1233 non-null   int64
#  1   name            1233 non-null   object
#  2   type            1231 non-null   object
#  3   height          1233 non-null   float64
#  4   weight          1233 non-null   float64
#  5   abilities       1231 non-null   object
#  6   hidden_ability  973 non-null    object
#  7   hp              1233 non-null   int64
#  8   attack          1233 non-null   int64
#  9   defense         1233 non-null   int64
#  10  sp_atk          1233 non-null   int64
#  11  sp_def          1233 non-null   int64
#  12  speed           1233 non-null   int64
#  13  legendary       1233 non-null   bool
#  14  mythical        1233 non-null   bool
#  15  generation      1233 non-null   object
# dtypes: bool(2), float64(2), int64(7), object(5)
# memory usage: 137.4+ KB

# %%
print("\n🔎 Valores nulos en el dataset:")
print(df_pokemon.isnull().sum())
# Out:
# 🔎 Valores nulos en el dataset:
# index               0
# name                0
# type                2
# height              0
# weight              0
# abilities           2
# hidden_ability    260
# hp                  0
# attack              0
# defense             0
# sp_atk              0
# sp_def              0
# speed               0
# legendary           0
# mythical            0
# generation          0
# dtype: int64

# %%
print("\n📌 Pokémon únicos en el dataset:")
print(df_pokemon["name"].nunique())
# Out:
# 📌 Pokémon únicos en el dataset:
# 1233

# %%
print("\n🔍 Duplicados en el dataset:")
print(df_pokemon.duplicated().sum())
# Out:
# 🔍 Duplicados en el dataset:
# 0

# %% [markdown]
# ### Eliminamos los Pokemon que tengan variante y tengan las mismas habilidades y estadísticas.

# %%
# Cargar el dataset original
df_pokemon = pd.read_csv(FINAL_SAVE_PATH_DATA_COLLECTION)

# Identificar Pokémon con formas alternativas
duplicated_pokemon = df_pokemon[df_pokemon.duplicated(subset=["index"], keep=False)]

# Columnas para comparación
stats_columns = ["hp", "attack", "defense", "sp_atk", "sp_def", "speed"]
ability_columns = ["abilities", "hidden_ability"]

# Lista para almacenar Pokémon filtrados
filtered_pokemon = []

# LOG: Pokémon que tienen variantes
print(f"🔎 Encontrados {duplicated_pokemon['index'].nunique()} Pokémon con formas alternativas.")

# Iterar por cada Pokémon con formas alternativas
for index, group in duplicated_pokemon.groupby("index"):
    base_form = group.iloc[0]  # Tomamos la primera forma como base

    # LOG: Mostrar qué Pokémon estamos analizando
    print(f"\n🔍 Analizando {base_form['name']} (ID: {index}) - {len(group)} formas encontradas.")

    # Filtrar variantes distintas en estadísticas o habilidades
    unique_forms = group.drop_duplicates(subset=stats_columns + ability_columns)

    if len(unique_forms) > 1:
        # LOG: Si hay diferencias en habilidades o estadísticas, conservar todas las variantes
        print(f"✅ Variantes diferentes detectadas para {base_form['name']}. Se mantienen todas.")
        filtered_pokemon.append(unique_forms)
    else:
        # LOG: Si todas las variantes son idénticas, solo conservar la base
        print(f"❌ Todas las variantes de {base_form['name']} son idénticas. Se mantiene solo la base.")
        filtered_pokemon.append(base_form.to_frame().T)

# Concatenar todas las filas filtradas
df_filtered = pd.concat(filtered_pokemon, ignore_index=True)

# Verificar si los Pokémon base están en `df_filtered`
print("\n🔎 Verificando Pokémon filtrados antes de fusionar...")
print(df_filtered[df_filtered["name"].isin(["venusaur", "charizard", "blastoise"])].head())

# LOG: Pokémon filtrados y cuántos se conservaron
print(f"\n📊 Pokémon con formas que se han conservado tras el filtrado: {df_filtered.shape[0]}")

# Agregar Pokémon base sin variantes para completar el dataset
df_final = pd.concat([
    df_pokemon[~df_pokemon["index"].isin(duplicated_pokemon["index"])],  # Pokémon sin variantes
    df_filtered  # Pokémon con formas pero filtradas correctamente
], ignore_index=True)

# Verificar si `df_final` contiene los Pokémon base antes de guardarlo
print("\n🔎 Verificando Pokémon base en `df_final` antes de guardar...")
print(df_final[df_final["name"].isin(["venusaur", "charizard", "blastoise"])].head())

# LOG: Recuento final
print(f"📊 Pokémon totales en el dataset final: {df_final.shape[0]}")

# Resetear el índice
df_final.reset_index(drop=True, inplace=True)

# Guardar el dataset limpio

df_final.to_csv(FILTER_DATA_PATH, index=False)

print(f"✅ Dataset filtrado guardado correctamente en '{FILTER_DATA_PATH}'.")

# Verificar contenido del archivo guardado
df_check = pd.read_csv(FILTER_DATA_PATH)
print("\n🔎 Verificando contenido del CSV guardado...")
print(df_check[df_check["name"].isin(["venusaur", "charizard", "blastoise"])].head())
# Out:
# 🔎 Encontrados 158 Pokémon con formas alternativas.
#
# 🔍 Analizando venusaur (ID: 3) - 3 formas encontradas.
# ✅ Variantes diferentes detectadas para venusaur. Se mantienen todas.
#
# 🔍 Analizando charizard (ID: 6) - 4 formas encontradas.
# ✅ Variantes diferentes detectadas para charizard. Se mantienen todas.
#
# 🔍 Analizando blastoise (ID: 9) - 3 formas encontradas.
# ✅ Variantes diferentes detectadas para blastoise. Se mantienen todas.
#
# 🔍 Analizando butterfree (ID: 12) - 2 formas encontradas.
# ❌ Todas las variantes de butterfree son idénticas. Se mantiene solo la base.
#
# 🔍 Analizando beedrill (ID: 15) - 2 formas encontradas.
# ✅ Variantes diferentes detectadas para beedrill. Se mantienen todas.
#
# 🔍 Analizando pidgeot (ID: 18) - 2 formas encontradas.
# ✅ Variantes diferentes detectadas para pidgeot. Se mantienen todas.
#
# 🔍 Analizando rattata (ID: 19) - 2 formas encontradas.
# ✅ Variantes diferentes detectadas para rattata. Se mantienen todas.
#
# 🔍 Analizando raticate (ID: 20) - 3 formas encontradas.
# ✅ Variantes diferentes detectadas para raticate. Se mantienen todas.
#
# 🔍 Analizando pikachu (ID: 25) - 17 formas encontradas.
# ✅ Variantes diferentes detectadas para pikachu. Se mantienen todas.
#
# 🔍 Analizando raichu (ID: 26) - 2 formas encontradas.
# ✅ Variantes diferentes detectadas para raichu. Se mantienen todas.
#
# 🔍 Analizando sandshrew (ID: 27) - 2 formas encontradas.
# ✅ Variantes diferentes detectadas para sandshrew. Se mantienen todas.
#
# 🔍 Analizando sandslash (ID: 28) - 2 formas encontradas.
# ✅ Variantes diferentes detectadas para sandslash. Se mantienen todas.
#
# 🔍 Analizando vulpix (ID: 37) - 2 formas encontradas.
# ✅ Variantes diferentes detectadas para vulpix. Se mantienen todas.
#
# 🔍 Analizando ninetales (ID: 38) - 2 formas encontradas.
# ✅ Variantes diferentes detectadas para ninetales. Se mantienen todas.
#
# 🔍 Analizando diglett (ID: 50) - 2 formas encontradas.
# ✅ Variantes diferentes detectadas para diglett. Se mantienen todas.
#
# 🔍 Analizando dugtrio (ID: 51) - 2 formas encontradas.
# ✅ Variantes diferentes detectadas para dugtrio. Se mantienen todas.
#
# 🔍 Analizando meowth (ID: 52) - 4 formas encontradas.
# ✅ Variantes diferentes detectadas para meowth. Se mantienen todas.
#
# 🔍 Analizando persian (ID: 53) - 2 formas encontradas.
# ✅ Variantes diferentes detectadas para persian. Se mantienen todas.
#
# 🔍 Analizando growlithe (ID: 58) - 2 formas encontradas.
# ✅ Variantes diferentes detectadas para growlithe. Se mantienen todas.
#
# 🔍 Analizando arcanine (ID: 59) - 2 formas encontradas.
# ✅ Variantes diferentes detectadas para arcanine. Se mantienen todas.
#
# 🔍 Analizando alakazam (ID: 65) - 2 formas encontradas.
# ✅ Variantes diferentes detectadas para alakazam. Se mantienen todas.
#
# 🔍 Analizando machamp (ID: 68) - 2 formas encontradas.
# ❌ Todas las variantes de machamp son idénticas. Se mantiene solo la base.
#
# 🔍 Analizando geodude (ID: 74) - 2 formas encontradas.
# ✅ Variantes diferentes detectadas para geodude. Se mantienen todas.
#
# 🔍 Analizando graveler (ID: 75) - 2 formas encontradas.
# ✅ Variantes diferentes detectadas para graveler. Se mantienen todas.
#
# 🔍 Analizando golem (ID: 76) - 2 formas encontradas.
# ✅ Variantes diferentes detectadas para golem. Se mantienen todas.
#
# 🔍 Analizando ponyta (ID: 77) - 2 formas encontradas.
# ✅ Variantes diferentes detectadas para ponyta. Se mantienen todas.
#
# 🔍 Analizando rapidash (ID: 78) - 2 formas encontradas.
# ✅ Variantes diferentes detectadas para rapidash. Se mantienen todas.
#
# 🔍 Analizando slowpoke (ID: 79) - 2 formas encontradas.
# ✅ Variantes diferentes detectadas para slowpoke. Se mantienen todas.
#
# 🔍 Analizando slowbro (ID: 80) - 3 formas encontradas.
# ✅ Variantes diferentes detectadas para slowbro. Se mantienen todas.
#
# 🔍 Analizando farfetchd (ID: 83) - 2 formas encontradas.
# ✅ Variantes diferentes detectadas para farfetchd. Se mantienen todas.
#
# 🔍 Analizando grimer (ID: 88) - 2 formas encontradas.
# ✅ Variantes diferentes detectadas para grimer. Se mantienen todas.
#
# 🔍 Analizando muk (ID: 89) - 2 formas encontradas.
# ✅ Variantes diferentes detectadas para muk. Se mantienen todas.
#
# 🔍 Analizando gengar (ID: 94) - 3 formas encontradas.
# ✅ Variantes diferentes detectadas para gengar. Se mantienen todas.
#
# 🔍 Analizando kingler (ID: 99) - 2 formas encontradas.
# ❌ Todas las variantes de kingler son idénticas. Se mantiene solo la base.
#
# 🔍 Analizando voltorb (ID: 100) - 2 formas encontradas.
# ❌ Todas las variantes de voltorb son idénticas. Se mantiene solo la base.
#
# 🔍 Analizando electrode (ID: 101) - 2 formas encontradas.
# ❌ Todas las variantes de electrode son idénticas. Se mantiene solo la base.
#
# 🔍 Analizando exeggutor (ID: 103) - 2 formas encontradas.
# ✅ Variantes diferentes detectadas para exeggutor. Se mantienen todas.
#
# 🔍 Analizando marowak (ID: 105) - 3 formas encontradas.
# ✅ Variantes diferentes detectadas para marowak. Se mantienen todas.
#
# 🔍 Analizando weezing (ID: 110) - 2 formas encontradas.
# ✅ Variantes diferentes detectadas para weezing. Se mantienen todas.
#
# 🔍 Analizando kangaskhan (ID: 115) - 2 formas encontradas.
# ✅ Variantes diferentes detectadas para kangaskhan. Se mantienen todas.
#
# 🔍 Analizando mr-mime (ID: 122) - 2 formas encontradas.
# ✅ Variantes diferentes detectadas para mr-mime. Se mantienen todas.
#
# 🔍 Analizando pinsir (ID: 127) - 2 formas encontradas.
# ✅ Variantes diferentes detectadas para pinsir. Se mantienen todas.
#
# 🔍 Analizando tauros (ID: 128) - 4 formas encontradas.
# ✅ Variantes diferentes detectadas para tauros. Se mantienen todas.
#
# 🔍 Analizando gyarados (ID: 130) - 2 formas encontradas.
# ✅ Variantes diferentes detectadas para gyarados. Se mantienen todas.
#
# 🔍 Analizando lapras (ID: 131) - 2 formas encontradas.
# ❌ Todas las variantes de lapras son idénticas. Se mantiene solo la base.
#
# 🔍 Analizando eevee (ID: 133) - 3 formas encontradas.
# ✅ Variantes diferentes detectadas para eevee. Se mantienen todas.
#
# 🔍 Analizando aerodactyl (ID: 142) - 2 formas encontradas.
# ✅ Variantes diferentes detectadas para aerodactyl. Se mantienen todas.
#
# 🔍 Analizando snorlax (ID: 143) - 2 formas encontradas.
# ❌ Todas las variantes de snorlax son idénticas. Se mantiene solo la base.
#
# 🔍 Analizando articuno (ID: 144) - 2 formas encontradas.
# ✅ Variantes diferentes detectadas para articuno. Se mantienen todas.
#
# 🔍 Analizando zapdos (ID: 145) - 2 formas encontradas.
# ✅ Variantes diferentes detectadas para zapdos. Se mantienen todas.
#
# 🔍 Analizando moltres (ID: 146) - 2 formas encontradas.
# ✅ Variantes diferentes detectadas para moltres. Se mantienen todas.
#
# 🔍 Analizando mewtwo (ID: 150) - 3 formas encontradas.
# ✅ Variantes diferentes detectadas para mewtwo. Se mantienen todas.
#
# 🔍 Analizando typhlosion (ID: 157) - 2 formas encontradas.
# ✅ Variantes diferentes detectadas para typhlosion. Se mantienen todas.
#
# 🔍 Analizando ampharos (ID: 181) - 2 formas encontradas.
# ✅ Variantes diferentes detectadas para ampharos. Se mantienen todas.
#
# 🔍 Analizando wooper (ID: 194) - 2 formas encontradas.
# ✅ Variantes diferentes detectadas para wooper. Se mantienen todas.
#
# 🔍 Analizando slowking (ID: 199) - 2 formas encontradas.
# ✅ Variantes diferentes detectadas para slowking. Se mantienen todas.
#
# 🔍 Analizando steelix (ID: 208) - 2 formas encontradas.
# ✅ Variantes diferentes detectadas para steelix. Se mantienen todas.
#
# 🔍 Analizando qwilfish (ID: 211) - 2 formas encontradas.
# ❌ Todas las variantes de qwilfish son idénticas. Se mantiene solo la base.
#
# 🔍 Analizando scizor (ID: 212) - 2 formas encontradas.
# ✅ Variantes diferentes detectadas para scizor. Se mantienen todas.
#
# 🔍 Analizando heracross (ID: 214) - 2 formas encontradas.
# ✅ Variantes diferentes detectadas para heracross. Se mantienen todas.
#
# 🔍 Analizando sneasel (ID: 215) - 2 formas encontradas.
# ❌ Todas las variantes de sneasel son idénticas. Se mantiene solo la base.
#
# 🔍 Analizando corsola (ID: 222) - 2 formas encontradas.
# ✅ Variantes diferentes detectadas para corsola. Se mantienen todas.
#
# 🔍 Analizando houndoom (ID: 229) - 2 formas encontradas.
# ✅ Variantes diferentes detectadas para houndoom. Se mantienen todas.
#
# 🔍 Analizando tyranitar (ID: 248) - 2 formas encontradas.
# ✅ Variantes diferentes detectadas para tyranitar. Se mantienen todas.
#
# 🔍 Analizando sceptile (ID: 254) - 2 formas encontradas.
# ✅ Variantes diferentes detectadas para sceptile. Se mantienen todas.
#
# 🔍 Analizando blaziken (ID: 257) - 2 formas encontradas.
# ✅ Variantes diferentes detectadas para blaziken. Se mantienen todas.
#
# 🔍 Analizando swampert (ID: 260) - 2 formas encontradas.
# ✅ Variantes diferentes detectadas para swampert. Se mantienen todas.
#
# 🔍 Analizando zigzagoon (ID: 263) - 2 formas encontradas.
# ❌ Todas las variantes de zigzagoon son idénticas. Se mantiene solo la base.
#
# 🔍 Analizando linoone (ID: 264) - 2 formas encontradas.
# ❌ Todas las variantes de linoone son idénticas. Se mantiene solo la base.
#
# 🔍 Analizando gardevoir (ID: 282) - 2 formas encontradas.
# ✅ Variantes diferentes detectadas para gardevoir. Se mantienen todas.
#
# 🔍 Analizando sableye (ID: 302) - 2 formas encontradas.
# ✅ Variantes diferentes detectadas para sableye. Se mantienen todas.
#
# 🔍 Analizando mawile (ID: 303) - 2 formas encontradas.
# ✅ Variantes diferentes detectadas para mawile. Se mantienen todas.
#
# 🔍 Analizando aggron (ID: 306) - 2 formas encontradas.
# ✅ Variantes diferentes detectadas para aggron. Se mantienen todas.
#
# 🔍 Analizando medicham (ID: 308) - 2 formas encontradas.
# ✅ Variantes diferentes detectadas para medicham. Se mantienen todas.
#
# 🔍 Analizando manectric (ID: 310) - 2 formas encontradas.
# ✅ Variantes diferentes detectadas para manectric. Se mantienen todas.
#
# 🔍 Analizando sharpedo (ID: 319) - 2 formas encontradas.
# ✅ Variantes diferentes detectadas para sharpedo. Se mantienen todas.
#
# 🔍 Analizando camerupt (ID: 323) - 2 formas encontradas.
# ✅ Variantes diferentes detectadas para camerupt. Se mantienen todas.
#
# 🔍 Analizando altaria (ID: 334) - 2 formas encontradas.
# ✅ Variantes diferentes detectadas para altaria. Se mantienen todas.
#
# 🔍 Analizando castform (ID: 351) - 4 formas encontradas.
# ❌ Todas las variantes de castform son idénticas. Se mantiene solo la base.
#
# 🔍 Analizando banette (ID: 354) - 2 formas encontradas.
# ✅ Variantes diferentes detectadas para banette. Se mantienen todas.
#
# 🔍 Analizando absol (ID: 359) - 2 formas encontradas.
# ✅ Variantes diferentes detectadas para absol. Se mantienen todas.
#
# 🔍 Analizando glalie (ID: 362) - 2 formas encontradas.
# ✅ Variantes diferentes detectadas para glalie. Se mantienen todas.
#
# 🔍 Analizando salamence (ID: 373) - 2 formas encontradas.
# ✅ Variantes diferentes detectadas para salamence. Se mantienen todas.
#
# 🔍 Analizando metagross (ID: 376) - 2 formas encontradas.
# ✅ Variantes diferentes detectadas para metagross. Se mantienen todas.
#
# 🔍 Analizando latias (ID: 380) - 2 formas encontradas.
# ✅ Variantes diferentes detectadas para latias. Se mantienen todas.
#
# 🔍 Analizando latios (ID: 381) - 2 formas encontradas.
# ✅ Variantes diferentes detectadas para latios. Se mantienen todas.
#
# 🔍 Analizando kyogre (ID: 382) - 2 formas encontradas.
# ✅ Variantes diferentes detectadas para kyogre. Se mantienen todas.
#
# 🔍 Analizando groudon (ID: 383) - 2 formas encontradas.
# ✅ Variantes diferentes detectadas para groudon. Se mantienen todas.
#
# 🔍 Analizando rayquaza (ID: 384) - 2 formas encontradas.
# ✅ Variantes diferentes detectadas para rayquaza. Se mantienen todas.
#
# 🔍 Analizando lopunny (ID: 428) - 2 formas encontradas.
# ✅ Variantes diferentes detectadas para lopunny. Se mantienen todas.
#
# 🔍 Analizando garchomp (ID: 445) - 2 formas encontradas.
# ✅ Variantes diferentes detectadas para garchomp. Se mantienen todas.
#
# 🔍 Analizando lucario (ID: 448) - 2 formas encontradas.
# ✅ Variantes diferentes detectadas para lucario. Se mantienen todas.
#
# 🔍 Analizando abomasnow (ID: 460) - 2 formas encontradas.
# ✅ Variantes diferentes detectadas para abomasnow. Se mantienen todas.
#
# 🔍 Analizando gallade (ID: 475) - 2 formas encontradas.
# ✅ Variantes diferentes detectadas para gallade. Se mantienen todas.
#
# 🔍 Analizando rotom (ID: 479) - 6 formas encontradas.
# ✅ Variantes diferentes detectadas para rotom. Se mantienen todas.
#
# 🔍 Analizando dialga (ID: 483) - 2 formas encontradas.
# ✅ Variantes diferentes detectadas para dialga. Se mantienen todas.
#
# 🔍 Analizando palkia (ID: 484) - 2 formas encontradas.
# ✅ Variantes diferentes detectadas para palkia. Se mantienen todas.
#
# 🔍 Analizando samurott (ID: 503) - 2 formas encontradas.
# ✅ Variantes diferentes detectadas para samurott. Se mantienen todas.
#
# 🔍 Analizando audino (ID: 531) - 2 formas encontradas.
# ✅ Variantes diferentes detectadas para audino. Se mantienen todas.
#
# 🔍 Analizando lilligant (ID: 549) - 2 formas encontradas.
# ✅ Variantes diferentes detectadas para lilligant. Se mantienen todas.
#
# 🔍 Analizando darumaka (ID: 554) - 2 formas encontradas.
# ❌ Todas las variantes de darumaka son idénticas. Se mantiene solo la base.
#
# 🔍 Analizando yamask (ID: 562) - 2 formas encontradas.
# ✅ Variantes diferentes detectadas para yamask. Se mantienen todas.
#
# 🔍 Analizando garbodor (ID: 569) - 2 formas encontradas.
# ❌ Todas las variantes de garbodor son idénticas. Se mantiene solo la base.
#
# 🔍 Analizando zorua (ID: 570) - 2 formas encontradas.
# ✅ Variantes diferentes detectadas para zorua. Se mantienen todas.
#
# 🔍 Analizando zoroark (ID: 571) - 2 formas encontradas.
# ✅ Variantes diferentes detectadas para zoroark. Se mantienen todas.
#
# 🔍 Analizando frillish (ID: 592) - 2 formas encontradas.
# ✅ Variantes diferentes detectadas para frillish. Se mantienen todas.
#
# 🔍 Analizando jellicent (ID: 593) - 2 formas encontradas.
# ✅ Variantes diferentes detectadas para jellicent. Se mantienen todas.
#
# 🔍 Analizando stunfisk (ID: 618) - 2 formas encontradas.
# ✅ Variantes diferentes detectadas para stunfisk. Se mantienen todas.
#
# 🔍 Analizando braviary (ID: 628) - 2 formas encontradas.
# ✅ Variantes diferentes detectadas para braviary. Se mantienen todas.
#
# 🔍 Analizando kyurem (ID: 646) - 3 formas encontradas.
# ✅ Variantes diferentes detectadas para kyurem. Se mantienen todas.
#
# 🔍 Analizando greninja (ID: 658) - 3 formas encontradas.
# ✅ Variantes diferentes detectadas para greninja. Se mantienen todas.
#
# 🔍 Analizando floette (ID: 670) - 2 formas encontradas.
# ✅ Variantes diferentes detectadas para floette. Se mantienen todas.
#
# 🔍 Analizando sliggoo (ID: 705) - 2 formas encontradas.
# ✅ Variantes diferentes detectadas para sliggoo. Se mantienen todas.
#
# 🔍 Analizando goodra (ID: 706) - 2 formas encontradas.
# ✅ Variantes diferentes detectadas para goodra. Se mantienen todas.
#
# 🔍 Analizando avalugg (ID: 713) - 2 formas encontradas.
# ✅ Variantes diferentes detectadas para avalugg. Se mantienen todas.
#
# 🔍 Analizando diancie (ID: 719) - 2 formas encontradas.
# ✅ Variantes diferentes detectadas para diancie. Se mantienen todas.
#
# 🔍 Analizando hoopa (ID: 720) - 2 formas encontradas.
# ✅ Variantes diferentes detectadas para hoopa. Se mantienen todas.
#
# 🔍 Analizando decidueye (ID: 724) - 2 formas encontradas.
# ✅ Variantes diferentes detectadas para decidueye. Se mantienen todas.
#
# 🔍 Analizando gumshoos (ID: 735) - 2 formas encontradas.
# ❌ Todas las variantes de gumshoos son idénticas. Se mantiene solo la base.
#
# 🔍 Analizando vikavolt (ID: 738) - 2 formas encontradas.
# ❌ Todas las variantes de vikavolt son idénticas. Se mantiene solo la base.
#
# 🔍 Analizando ribombee (ID: 743) - 2 formas encontradas.
# ❌ Todas las variantes de ribombee son idénticas. Se mantiene solo la base.
#
# 🔍 Analizando rockruff (ID: 744) - 2 formas encontradas.
# ✅ Variantes diferentes detectadas para rockruff. Se mantienen todas.
#
# 🔍 Analizando araquanid (ID: 752) - 2 formas encontradas.
# ❌ Todas las variantes de araquanid son idénticas. Se mantiene solo la base.
#
# 🔍 Analizando lurantis (ID: 754) - 2 formas encontradas.
# ❌ Todas las variantes de lurantis son idénticas. Se mantiene solo la base.
#
# 🔍 Analizando salazzle (ID: 758) - 2 formas encontradas.
# ❌ Todas las variantes de salazzle son idénticas. Se mantiene solo la base.
#
# 🔍 Analizando togedemaru (ID: 777) - 2 formas encontradas.
# ❌ Todas las variantes de togedemaru son idénticas. Se mantiene solo la base.
#
# 🔍 Analizando kommo-o (ID: 784) - 2 formas encontradas.
# ❌ Todas las variantes de kommo-o son idénticas. Se mantiene solo la base.
#
# 🔍 Analizando necrozma (ID: 800) - 4 formas encontradas.
# ✅ Variantes diferentes detectadas para necrozma. Se mantienen todas.
#
# 🔍 Analizando magearna (ID: 801) - 2 formas encontradas.
# ❌ Todas las variantes de magearna son idénticas. Se mantiene solo la base.
#
# 🔍 Analizando melmetal (ID: 809) - 2 formas encontradas.
# ❌ Todas las variantes de melmetal son idénticas. Se mantiene solo la base.
#
# 🔍 Analizando rillaboom (ID: 812) - 2 formas encontradas.
# ❌ Todas las variantes de rillaboom son idénticas. Se mantiene solo la base.
#
# 🔍 Analizando cinderace (ID: 815) - 2 formas encontradas.
# ❌ Todas las variantes de cinderace son idénticas. Se mantiene solo la base.
#
# 🔍 Analizando inteleon (ID: 818) - 2 formas encontradas.
# ❌ Todas las variantes de inteleon son idénticas. Se mantiene solo la base.
#
# 🔍 Analizando corviknight (ID: 823) - 2 formas encontradas.
# ❌ Todas las variantes de corviknight son idénticas. Se mantiene solo la base.
#
# 🔍 Analizando orbeetle (ID: 826) - 2 formas encontradas.
# ❌ Todas las variantes de orbeetle son idénticas. Se mantiene solo la base.
#
# 🔍 Analizando drednaw (ID: 834) - 2 formas encontradas.
# ❌ Todas las variantes de drednaw son idénticas. Se mantiene solo la base.
#
# 🔍 Analizando coalossal (ID: 839) - 2 formas encontradas.
# ❌ Todas las variantes de coalossal son idénticas. Se mantiene solo la base.
#
# 🔍 Analizando flapple (ID: 841) - 2 formas encontradas.
# ❌ Todas las variantes de flapple son idénticas. Se mantiene solo la base.
#
# 🔍 Analizando appletun (ID: 842) - 2 formas encontradas.
# ❌ Todas las variantes de appletun son idénticas. Se mantiene solo la base.
#
# 🔍 Analizando sandaconda (ID: 844) - 2 formas encontradas.
# ❌ Todas las variantes de sandaconda son idénticas. Se mantiene solo la base.
#
# 🔍 Analizando cramorant (ID: 845) - 3 formas encontradas.
# ❌ Todas las variantes de cramorant son idénticas. Se mantiene solo la base.
#
# 🔍 Analizando centiskorch (ID: 851) - 2 formas encontradas.
# ❌ Todas las variantes de centiskorch son idénticas. Se mantiene solo la base.
#
# 🔍 Analizando hatterene (ID: 858) - 2 formas encontradas.
# ❌ Todas las variantes de hatterene son idénticas. Se mantiene solo la base.
#
# 🔍 Analizando grimmsnarl (ID: 861) - 2 formas encontradas.
# ❌ Todas las variantes de grimmsnarl son idénticas. Se mantiene solo la base.
#
# 🔍 Analizando alcremie (ID: 869) - 2 formas encontradas.
# ❌ Todas las variantes de alcremie son idénticas. Se mantiene solo la base.
#
# 🔍 Analizando copperajah (ID: 879) - 2 formas encontradas.
# ❌ Todas las variantes de copperajah son idénticas. Se mantiene solo la base.
#
# 🔍 Analizando duraludon (ID: 884) - 2 formas encontradas.
# ❌ Todas las variantes de duraludon son idénticas. Se mantiene solo la base.
#
# 🔍 Analizando zacian (ID: 888) - 2 formas encontradas.
# ✅ Variantes diferentes detectadas para zacian. Se mantienen todas.
#
# 🔍 Analizando zamazenta (ID: 889) - 2 formas encontradas.
# ✅ Variantes diferentes detectadas para zamazenta. Se mantienen todas.
#
# 🔍 Analizando eternatus (ID: 890) - 2 formas encontradas.
# ✅ Variantes diferentes detectadas para eternatus. Se mantienen todas.
#
# 🔍 Analizando zarude (ID: 893) - 2 formas encontradas.
# ❌ Todas las variantes de zarude son idénticas. Se mantiene solo la base.
#
# 🔍 Analizando calyrex (ID: 898) - 3 formas encontradas.
# ✅ Variantes diferentes detectadas para calyrex. Se mantienen todas.
#
# 🔍 Analizando ursaluna (ID: 901) - 2 formas encontradas.
# ✅ Variantes diferentes detectadas para ursaluna. Se mantienen todas.
#
# 🔍 Analizando gimmighoul (ID: 999) - 2 formas encontradas.
# ✅ Variantes diferentes detectadas para gimmighoul. Se mantienen todas.
#
# 🔍 Analizando koraidon (ID: 1007) - 5 formas encontradas.
# ✅ Variantes diferentes detectadas para koraidon. Se mantienen todas.
#
# 🔍 Analizando miraidon (ID: 1008) - 5 formas encontradas.
# ✅ Variantes diferentes detectadas para miraidon. Se mantienen todas.
#
# 🔍 Analizando ogerpon (ID: 1017) - 4 formas encontradas.
# ✅ Variantes diferentes detectadas para ogerpon. Se mantienen todas.
#
# 🔍 Analizando terapagos (ID: 1024) - 3 formas encontradas.
# ✅ Variantes diferentes detectadas para terapagos. Se mantienen todas.
#
# 🔎 Verificando Pokémon filtrados antes de fusionar...
#   index       name            type height weight abilities hidden_ability  hp  \
# 0     3   venusaur  grass / poison    2.0  100.0  overgrow    chlorophyll  80
# 2     6  charizard   fire / flying    1.7   90.5     blaze    solar-power  78
# 5     9  blastoise           water    1.6   85.5   torrent      rain-dish  79
#
#   attack defense sp_atk sp_def speed legendary mythical    generation
# 0     82      83    100    100    80     False    False  generation-i
# 2     84      78    109     85   100     False    False  generation-i
# 5     83     100     85    105    78     False    False  generation-i
#
# 📊 Pokémon con formas que se han conservado tras el filtrado: 286
#
# 🔎 Verificando Pokémon base en `df_final` antes de guardar...
#     index       name            type height weight abilities hidden_ability  \
# 867     3   venusaur  grass / poison    2.0  100.0  overgrow    chlorophyll
# 869     6  charizard   fire / flying    1.7   90.5     blaze    solar-power
# 872     9  blastoise           water    1.6   85.5   torrent      rain-dish
#
#      hp attack defense sp_atk sp_def speed legendary mythical    generation
# 867  80     82      83    100    100    80     False    False  generation-i
# 869  78     84      78    109     85   100     False    False  generation-i
# 872  79     83     100     85    105    78     False    False  generation-i
# 📊 Pokémon totales en el dataset final: 1153
# ✅ Dataset filtrado guardado correctamente en '../data/data_filtered/pokemon_filtered_data.csv'.
#
# 🔎 Verificando contenido del CSV guardado...
#      index       name            type  height  weight abilities  \
# 867      3   venusaur  grass / poison     2.0   100.0  overgrow
# 869      6  charizard   fire / flying     1.7    90.5     blaze
# 872      9  blastoise           water     1.6    85.5   torrent
#
#     hidden_ability  hp  attack  defense  sp_atk  sp_def  speed  legendary  \
# 867    chlorophyll  80      82       83     100     100     80      False
# 869    solar-power  78      84       78     109      85    100      False
# 872      rain-dish  79      83      100      85     105     78      False
#
#      mythical    generation
# 867     False  generation-i
# 869     False  generation-i
# 872     False  generation-i

# %% [markdown]
# ### Ordenamos por Nº de Pokedex y Nombre base siempre primero

# %%
# Cargar el archivo CSV filtrado

df_final = pd.read_csv(FILTER_DATA_PATH)

# Crear una nueva columna para identificar la forma base (sin '-')
df_final["is_base"] = df_final["name"].apply(lambda x: "-" not in x)

# Ordenar por index y asegurarse de que la forma base quede en primer lugar
df_final = df_final.sort_values(by=["index", "is_base"], ascending=[True, False]).reset_index(drop=True)

# Eliminar la columna auxiliar "is_base" después de ordenar
df_final.drop(columns=["is_base"], inplace=True)

# Guardar nuevamente el CSV ordenado correctamente

df_final.to_csv(SORTED_FILTER_DATA_PATH, index=False)

print(f"✅ Dataset ordenado y limpio guardado correctamente en '{SORTED_FILTER_DATA_PATH}'.")

# Mostrar las primeras filas para verificar
df_final.head(20)
# Out:
# ✅ Dataset ordenado y limpio guardado correctamente en '../data/data_filtered/pokemon_filtered_sorted_data.csv'.
#     index              name            type  height  weight      abilities  \
# 0       1         bulbasaur  grass / poison     0.7     6.9       overgrow
# 1       2           ivysaur  grass / poison     1.0    13.0       overgrow
# 2       3          venusaur  grass / poison     2.0   100.0       overgrow
# 3       3     venusaur-mega  grass / poison     2.4   155.5      thick-fat
# 4       4        charmander            fire     0.6     8.5          blaze
# 5       5        charmeleon            fire     1.1    19.0          blaze
# 6       6         charizard   fire / flying     1.7    90.5          blaze
# 7       6  charizard-mega-x   fire / dragon     1.7   110.5    tough-claws
# 8       6  charizard-mega-y   fire / flying     1.7   100.5        drought
# 9       7          squirtle           water     0.5     9.0        torrent
# 10      8         wartortle           water     1.0    22.5        torrent
# 11      9         blastoise           water     1.6    85.5        torrent
# 12      9    blastoise-mega           water     1.6   101.1  mega-launcher
# 13     10          caterpie             bug     0.3     2.9    shield-dust
# 14     11           metapod             bug     0.7     9.9      shed-skin
# 15     12        butterfree    bug / flying     1.1    32.0  compound-eyes
# 16     13            weedle    bug / poison     0.3     3.2    shield-dust
# 17     14            kakuna    bug / poison     0.6    10.0      shed-skin
# 18     15          beedrill    bug / poison     1.0    29.5          swarm
# 19     15     beedrill-mega    bug / poison     1.4    40.5   adaptability
#
#    hidden_ability  hp  attack  defense  sp_atk  sp_def  speed  legendary  \
# 0     chlorophyll  45      49       49      65      65     45      False
# 1     chlorophyll  60      62       63      80      80     60      False
# 2     chlorophyll  80      82       83     100     100     80      False
# 3             NaN  80     100      123     122     120     80      False
# 4     solar-power  39      52       43      60      50     65      False
# 5     solar-power  58      64       58      80      65     80      False
# 6     solar-power  78      84       78     109      85    100      False
# 7             NaN  78     130      111     130      85    100      False
# 8             NaN  78     104       78     159     115    100      False
# 9       rain-dish  44      48       65      50      64     43      False
# 10      rain-dish  59      63       80      65      80     58      False
# 11      rain-dish  79      83      100      85     105     78      False
# 12            NaN  79     103      120     135     115     78      False
# 13       run-away  45      30       35      20      20     45      False
# 14            NaN  50      20       55      25      25     30      False
# 15    tinted-lens  60      45       50      90      80     70      False
# 16       run-away  40      35       30      20      20     50      False
# 17            NaN  45      25       50      25      25     35      False
# 18         sniper  65      90       40      45      80     75      False
# 19            NaN  65     150       40      15      80    145      False
#
#     mythical    generation
# 0      False  generation-i
# 1      False  generation-i
# 2      False  generation-i
# 3      False  generation-i
# 4      False  generation-i
# 5      False  generation-i
# 6      False  generation-i
# 7      False  generation-i
# 8      False  generation-i
# 9      False  generation-i
# 10     False  generation-i
# 11     False  generation-i
# 12     False  generation-i
# 13     False  generation-i
# 14     False  generation-i
# 15     False  generation-i
# 16     False  generation-i
# 17     False  generation-i
# 18     False  generation-i
# 19     False  generation-i

# %% [markdown]
# ### Eliminar a frillish-female y jellicent-female, ya que dan errores

# %%
# Cargar el dataset en un DataFrame
df = pd.read_csv(SORTED_FILTER_DATA_PATH)

# Eliminar las filas con los nombres específicos
df = df[~df["name"].isin(["frillish-female", "jellicent-female"])]

# Guardar el dataset actualizado
df.to_csv(SORTED_FILTER_DATA_PATH, index=False)

print("✅ Filas eliminadas y dataset actualizado correctamente.")
# Out:
# ✅ Filas eliminadas y dataset actualizado correctamente.

# %% [markdown]
# ### Rellenar valores nulos de "hidden_ability" con valor "None" y crear columna "total_stats" con la suma de todas las estadísticas base

# %%
# Cargar el archivo CSV ordenado

df = pd.read_csv(SORTED_FILTER_DATA_PATH)

# Rellenar valores nulos en la columna "hidden_ability" con "None"
df["hidden_ability"].fillna("None ", inplace=True)

# Crear la nueva columna "total_stats" sumando todas las estadísticas base
stats_columns = ["hp", "attack", "defense", "sp_atk", "sp_def", "speed"]
df["total_stats"] = df[stats_columns].sum(axis=1)

columns_to_convert = ["index", "height", "weight", "hp", "attack", "defense", "sp_atk", "sp_def", "speed", "total_stats"]
df[columns_to_convert] = df[columns_to_convert].astype(int)

# Guardar el dataset actualizado
df.to_csv(SORTED_FILTER_DATA_PATH_CLEANED, index=False)

print(f"✅ Dataset actualizado y guardado en '{SORTED_FILTER_DATA_PATH_CLEANED}'.")

# Mostrar una muestra de los datos para verificar
display(df.head(20))
# Out:
# ✅ Dataset actualizado y guardado en '../data/data_filtered/pokemon_filtered_sorted_data_cleaned.csv'.
# C:\Users\furio\AppData\Local\Temp\ipykernel_19892\301948155.py:6: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df["hidden_ability"].fillna("None ", inplace=True)
#     index              name            type  height  weight      abilities  \
# 0       1         bulbasaur  grass / poison       0       6       overgrow
# 1       2           ivysaur  grass / poison       1      13       overgrow
# 2       3          venusaur  grass / poison       2     100       overgrow
# 3       3     venusaur-mega  grass / poison       2     155      thick-fat
# 4       4        charmander            fire       0       8          blaze
# 5       5        charmeleon            fire       1      19          blaze
# 6       6         charizard   fire / flying       1      90          blaze
# 7       6  charizard-mega-x   fire / dragon       1     110    tough-claws
# 8       6  charizard-mega-y   fire / flying       1     100        drought
# 9       7          squirtle           water       0       9        torrent
# 10      8         wartortle           water       1      22        torrent
# 11      9         blastoise           water       1      85        torrent
# 12      9    blastoise-mega           water       1     101  mega-launcher
# 13     10          caterpie             bug       0       2    shield-dust
# 14     11           metapod             bug       0       9      shed-skin
# 15     12        butterfree    bug / flying       1      32  compound-eyes
# 16     13            weedle    bug / poison       0       3    shield-dust
# 17     14            kakuna    bug / poison       0      10      shed-skin
# 18     15          beedrill    bug / poison       1      29          swarm
# 19     15     beedrill-mega    bug / poison       1      40   adaptability
#
#    hidden_ability  hp  attack  defense  sp_atk  sp_def  speed  legendary  \
# 0     chlorophyll  45      49       49      65      65     45      False
# 1     chlorophyll  60      62       63      80      80     60      False
# 2     chlorophyll  80      82       83     100     100     80      False
# 3           None   80     100      123     122     120     80      False
# 4     solar-power  39      52       43      60      50     65      False
# 5     solar-power  58      64       58      80      65     80      False
# 6     solar-power  78      84       78     109      85    100      False
# 7           None   78     130      111     130      85    100      False
# 8           None   78     104       78     159     115    100      False
# 9       rain-dish  44      48       65      50      64     43      False
# 10      rain-dish  59      63       80      65      80     58      False
# 11      rain-dish  79      83      100      85     105     78      False
# 12          None   79     103      120     135     115     78      False
# 13       run-away  45      30       35      20      20     45      False
# 14          None   50      20       55      25      25     30      False
# 15    tinted-lens  60      45       50      90      80     70      False
# 16       run-away  40      35       30      20      20     50      False
# 17          None   45      25       50      25      25     35      False
# 18         sniper  65      90       40      45      80     75      False
# 19          None   65     150       40      15      80    145      False
#
#     mythical    generation  total_stats
# 0      False  generation-i          318
# 1      False  generation-i          405
# 2      False  generation-i          525
# 3      False  generation-i          625
# 4      False  generation-i          309
# 5      False  generation-i          405
# 6      False  generation-i          534
# 7      False  generation-i          634
# 8      False  generation-i          634
# 9      False  generation-i          314
# 10     False  generation-i          405
# 11     False  generation-i          530
# 12     False  generation-i          630
# 13     False  generation-i          195
# 14     False  generation-i          205
# 15     False  generation-i          395
# 16     False  generation-i          195
# 17     False  generation-i          205
# 18     False  generation-i          395
# 19     False  generation-i          495

# %% [markdown]
# ### Verificamos que no tenemos valores nulos

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1151 entries, 0 to 1150
# Data columns (total 17 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   index           1151 non-null   int64
#  1   name            1151 non-null   object
#  2   type            1151 non-null   object
#  3   height          1151 non-null   int64
#  4   weight          1151 non-null   int64
#  5   abilities       1151 non-null   object
#  6   hidden_ability  1151 non-null   object
#  7   hp              1151 non-null   int64
#  8   attack          1151 non-null   int64
#  9   defense         1151 non-null   int64
#  10  sp_atk          1151 non-null   int64
#  11  sp_def          1151 non-null   int64
#  12  speed           1151 non-null   int64
#  13  legendary       1151 non-null   bool
#  14  mythical        1151 non-null   bool
#  15  generation      1151 non-null   object
#  16  total_stats     1151 non-null   int64
# dtypes: bool(2), int64(10), object(5)
# memory usage: 137.3+ KB

# %% [markdown]
# ### Ya tenemos el dataset final, lo renombramos a pokemon_dataset_final.csv

# %%
import shutil

# Ruta del archivo original y nuevo nombre
old_path = SORTED_FILTER_DATA_PATH_CLEANED
new_path = FINAL_DATASET_PATH

# Copiar el archivo
shutil.copy(old_path, new_path)

print("✅ El archivo ha sido copiado correctamente como 'pokemon_dataset_final.csv'.")
# Out:
# ✅ El archivo ha sido copiado correctamente como 'pokemon_dataset_final.csv'.

# %%
df = pd.read_csv(FINAL_DATASET_PATH)
df.head(12)
# Out:
#     index              name            type  height  weight    abilities  \
# 0       1         bulbasaur  grass / poison       0       6     overgrow
# 1       2           ivysaur  grass / poison       1      13     overgrow
# 2       3          venusaur  grass / poison       2     100     overgrow
# 3       3     venusaur-mega  grass / poison       2     155    thick-fat
# 4       4        charmander            fire       0       8        blaze
# 5       5        charmeleon            fire       1      19        blaze
# 6       6         charizard   fire / flying       1      90        blaze
# 7       6  charizard-mega-x   fire / dragon       1     110  tough-claws
# 8       6  charizard-mega-y   fire / flying       1     100      drought
# 9       7          squirtle           water       0       9      torrent
# 10      8         wartortle           water       1      22      torrent
# 11      9         blastoise           water       1      85      torrent
#
#    hidden_ability  hp  attack  defense  sp_atk  sp_def  speed  legendary  \
# 0     chlorophyll  45      49       49      65      65     45      False
# 1     chlorophyll  60      62       63      80      80     60      False
# 2     chlorophyll  80      82       83     100     100     80      False
# 3           None   80     100      123     122     120     80      False
# 4     solar-power  39      52       43      60      50     65      False
# 5     solar-power  58      64       58      80      65     80      False
# 6     solar-power  78      84       78     109      85    100      False
# 7           None   78     130      111     130      85    100      False
# 8           None   78     104       78     159     115    100      False
# 9       rain-dish  44      48       65      50      64     43      False
# 10      rain-dish  59      63       80      65      80     58      False
# 11      rain-dish  79      83      100      85     105     78      False
#
#     mythical    generation  total_stats
# 0      False  generation-i          318
# 1      False  generation-i          405
# 2      False  generation-i          525
# 3      False  generation-i          625
# 4      False  generation-i          309
# 5      False  generation-i          405
# 6      False  generation-i          534
# 7      False  generation-i          634
# 8      False  generation-i          634
# 9      False  generation-i          314
# 10     False  generation-i          405
# 11     False  generation-i          530

# %%
# Mostrar las filas donde 'hidden_ability' es nulo
df_null_hidden_ability = df[df["hidden_ability"].isna()]

# Mostrar el resultado en el notebook
print(df_null_hidden_ability)
# Out:
# Empty DataFrame
# Columns: [index, name, type, height, weight, abilities, hidden_ability, hp, attack, defense, sp_atk, sp_def, speed, legendary, mythical, generation, total_stats]
# Index: []
